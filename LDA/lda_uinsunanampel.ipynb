# %%
# !pip install pyLDAvis
# Out:
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %%
dir = "D:\ANISA\Kuliah\Tugas\Semester 5\Text Analytics\publikasi"
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\A'
# <>:1: SyntaxWarning: invalid escape sequence '\A'
# C:\Users\User\AppData\Local\Temp\ipykernel_3944\120945336.py:1: SyntaxWarning: invalid escape sequence '\A'
#   dir = "D:\ANISA\Kuliah\Tugas\Semester 5\Text Analytics\publikasi"

# %%
import pandas as pd

UINSunanAmpel = pd.read_csv(f"{dir}\preprocessing\preprocessing_UINSunanAmpel.csv")
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\p'
# <>:3: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\User\AppData\Local\Temp\ipykernel_3944\1974702071.py:3: SyntaxWarning: invalid escape sequence '\p'
#   UINSunanAmpel = pd.read_csv(f"{dir}\preprocessing\preprocessing_UINSunanAmpel.csv")

# %%
text = UINSunanAmpel["abstract"]
text_list =  [i.split() for i in text]
print(len(text_list))
print(text_list)
# Out:
# 301
# ...

# %% [markdown]
# ## Bigrams dan Tigrams

# %%
import gensim
#Create Bigram & Trigram Models
from gensim.models import Phrases
# Add bigrams and trigrams to docs, minimum count 10 means only that appear 10 times or more.
bigram = Phrases(text_list, min_count=10)
trigram = Phrases(bigram[text_list])
for idx in range(len(text_list)):
    for token in bigram[text_list[idx]]:
        if '_' in token:
            # Token is a bigram, add to document.
            text_list[idx].append(token)
    for token in trigram[text_list[idx]]:
        if '_' in token:
            # Token is a bigram, add to document.
            text_list[idx].append(token)

# %%
print(text_list)
# Out:
# [['himpun', 'kumpul', 'objek', 'definisi', 'ruang', 'vektor', 'himpun', 'kosong', 'lapang', 'lengkap', 'operasi', 'penuh', 'aksioma', 'aksioma', 'ruang', 'vektor', 'himpun', 'kosong', 'konstanta', 'lengkap', 'operasi', 'biner', 'aljabar', 'binary', 'constants', 'penuh', 'aksioma', 'aksioma', 'aljabar', 'ruang', 'vektor', 'lapang', 'lengkap', 'meta', 'bilinier', 'penuh', 'aksioma', 'aksioma', 'aljabar', 'aljabar', 'sifat', 'aljabar', 'bentuk', 'aljabar', 'tuju', 'teliti', 'karakteristik', 'aljabar', 'aljabar', 'dasar', 'sifat', 'aljabar', 'analis', 'hubung', 'aljabar', 'aljabar', 'definisi', 'aljabar', 'pseudo', 'analis', 'hubung', 'aljabar', 'pseudo', 'aljabar', 'dasar', 'analisa', 'dapat', 'sifat', 'sifat', 'aljabar', 'aljabar', 'aljabar', 'pseudo', 'sifat', 'sifat', 'aljabar', 'bentuk', 'aljabar', 'syarat', 'elemen', 'aljabar', 'aljabar', 'abelian', 'bentuk', 'aljabar', 'sifat', 'sifat', 'aljabar', 'pseudo', 'bentuk', 'aljabar', 'syarat', 'elemen', 'aljabar', 'aljabar', 'pseudo', '
# ...

# %%
from gensim import corpora, models
# Create a dictionary representation of the documents.
dictionary = corpora.Dictionary(text_list)
dictionary.filter_extremes(no_below=5, no_above=0.2)
#no_below (int, optional) – Keep tokens which are contained in at least no_below documents.
#no_above (float, optional) – Keep tokens which are contained in no more than no_above documents (fraction of total corpus size, not an absolute number).
print(dictionary)
# Out:
# Dictionary<849 unique tokens: ['aksioma', 'aljabar', 'aljabar_aljabar', 'analis', 'bentuk']...>

# %%
#https://radimrehurek.com/gensim/tut1.html
#build corpus
# Converting list of documents (corpus) into Document Term Matrix using dictionary prepared above.
doc_term_matrix = [dictionary.doc2bow(doc) for doc in text_list]
#The function doc2bow converts document (a list of words) into the bag-of-words format

# '''The function doc2bow() simply counts the number of occurrences of each distinct word,
# converts the word to its integer word id and returns the result as a sparse vector.
# The sparse vector [(0, 1), (1, 1)] therefore reads: in the document “Human computer interaction”,
# the words computer (id 0) and human (id 1) appear once;
# the other ten dictionary words appear (implicitly) zero times.'''

print(len(doc_term_matrix))
print(doc_term_matrix[100])
tfidf = models.TfidfModel(doc_term_matrix) #build TF-IDF model
corpus_tfidf = tfidf[doc_term_matrix]
# Out:
# 301
# [(23, 1), (30, 2), (60, 3), (93, 1), (118, 1), (149, 6), (161, 1), (165, 1), (166, 4), (167, 12), (168, 2), (170, 1), (175, 1), (177, 3), (193, 1), (196, 1), (224, 2), (244, 2), (247, 1), (248, 1), (258, 2), (259, 3), (266, 1), (277, 1), (287, 1), (291, 1), (306, 1), (449, 1), (459, 1), (472, 1), (541, 1), (548, 1), (555, 2), (580, 1), (581, 2), (599, 1), (615, 1), (630, 6), (645, 1), (646, 1), (764, 1), (765, 1), (779, 1), (781, 1)]

# %% [markdown]
# ## LDA

# %%
from gensim.models.ldamodel import LdaModel
import pyLDAvis.gensim
import pickle
import pyLDAvis
import os

pyLDAvis.enable_notebook()

for numTopic in range(2, 6):
  for passes in [100, 500, 1000, 5000]:
    print(f"numTopic: {numTopic}, passes: {passes} => Starting")
    model = LdaModel(corpus=corpus_tfidf, id2word=dictionary, num_topics=numTopic, passes=passes) #num topic
    model.save(f'{dir}/hasil LDA/LDA UIN Sunan Ampel/LDA model/lda_model_uinsunanampel_{str(numTopic)}_{passes}')

    LDAvis_data_filepath = os.path.join(f'{dir}/hasil LDA/LDA UIN Sunan Ampel/ldavis_prepared_uinsunanampel_{str(numTopic)}_{passes}')

    data = pyLDAvis.gensim.prepare(model, corpus_tfidf, dictionary)
    with open(LDAvis_data_filepath, 'wb') as f:
        pickle.dump(data, f)

    # load the pre-prepared pyLDAvis data from disk
    with open(LDAvis_data_filepath, 'rb') as f:
        data = pickle.load(f)

    pyLDAvis.save_html(data, f'{dir}/hasil LDA/LDA UIN Sunan Ampel/{str(numTopic)}_{passes}.html')

    # print(data)
    print(f"numTopic: {numTopic}, passes: {passes} => Success")
# Out:
# numTopic: 2, passes: 100 => Starting
# numTopic: 2, passes: 100 => Success
# numTopic: 2, passes: 500 => Starting
# numTopic: 2, passes: 500 => Success
# numTopic: 2, passes: 1000 => Starting
# numTopic: 2, passes: 1000 => Success
# numTopic: 2, passes: 5000 => Starting
# numTopic: 2, passes: 5000 => Success
# numTopic: 3, passes: 100 => Starting
# numTopic: 3, passes: 100 => Success
# numTopic: 3, passes: 500 => Starting
# numTopic: 3, passes: 500 => Success
# numTopic: 3, passes: 1000 => Starting
# numTopic: 3, passes: 1000 => Success
# numTopic: 3, passes: 5000 => Starting
# numTopic: 3, passes: 5000 => Success
# numTopic: 4, passes: 100 => Starting
# numTopic: 4, passes: 100 => Success
# numTopic: 4, passes: 500 => Starting
# numTopic: 4, passes: 500 => Success
# numTopic: 4, passes: 1000 => Starting
# numTopic: 4, passes: 1000 => Success
# numTopic: 4, passes: 5000 => Starting
# numTopic: 4, passes: 5000 => Success
# numTopic: 5, passes: 100 => Starting
# ...
