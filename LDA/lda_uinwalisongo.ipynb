# %%
# !pip install pyLDAvis
# Out:
# Requirement already satisfied: pyLDAvis in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (3.4.1)
# Requirement already satisfied: numpy>=1.24.2 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from pyLDAvis) (1.26.4)
# Requirement already satisfied: scipy in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from pyLDAvis) (1.13.1)
# Requirement already satisfied: pandas>=2.0.0 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from pyLDAvis) (2.2.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from pyLDAvis) (1.4.2)
# Requirement already satisfied: jinja2 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from pyLDAvis) (3.1.3)
# Requirement already satisfied: numexpr in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from pyLDAvis) (2.10.2)
# Requirement already satisfied: funcy in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from pyLDAvis) (2.0)
# Requirement already satisfied: scikit-learn>=1.0.0 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from pyLDAvis) (1.5.2)
# Requirement already satisfied: gensim in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from pyLDAvis) (4.3.3)
# Requirement already satisfied: setuptools in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from pyLDAvis) (75.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from pandas>=2.0.0->pyLDAvis) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from pandas>=2.0.0->pyLDAvis) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from pandas>=2.0.0->pyLDAvis) (2024.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn>=1.0.0->pyLDAvis) (3.5.0)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from gensim->pyLDAvis) (7.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from jinja2->pyLDAvis) (2.1.5)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->pyLDAvis) (1.16.0)
# Requirement already satisfied: wrapt in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from smart-open>=1.8.1->gensim->pyLDAvis) (1.16.0)
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
dir = "D:\ANISA\Kuliah\Tugas\Semester 5\Text Analytics\publikasi"
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\A'
# <>:1: SyntaxWarning: invalid escape sequence '\A'
# C:\Users\User\AppData\Local\Temp\ipykernel_14692\120945336.py:1: SyntaxWarning: invalid escape sequence '\A'
#   dir = "D:\ANISA\Kuliah\Tugas\Semester 5\Text Analytics\publikasi"

# %%
import pandas as pd

UINWalisongo = pd.read_csv(f"{dir}\preprocessing\preprocessing_UINWalisongo.csv")
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\p'
# <>:3: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\User\AppData\Local\Temp\ipykernel_14692\3254600680.py:3: SyntaxWarning: invalid escape sequence '\p'
#   UINWalisongo = pd.read_csv(f"{dir}\preprocessing\preprocessing_UINWalisongo.csv")

# %%
text = UINWalisongo["abstract"]
text_list =  [i.split() for i in text]
print(len(text_list))
print(text_list)
# Out:
# 88
# [['dekomposisi', 'salah', 'dekomposisi', 'matriks', 'dekomposisi', 'matriks', 'kali', 'matriks', 'ortogonal', 'matriks', 'segitiga', 'dekomposisi', 'aljabar', 'konvensional', 'bart', 'schutter', 'bart', 'moor', 'dekomposisi', 'aljabar', 'plus', 'simetri', 'aljabar', 'plus', 'simetri', 'struktur', 'aljabar', 'himpun', 'notasi', 'operasi', 'dasar', 'ajabar', 'plus', 'struktur', 'aljabar', 'himpun', 'operasi', 'dasar', 'jumlah', 'maksimum', 'operasi', 'dasar', 'kali', 'jumlah', 'aljabar', 'plus', 'milik', 'invers', 'operasi', 'bentuk', 'aljabar', 'plus', 'simetri', 'aljabar', 'plus', 'simetri', 'milik', 'kelas', 'himpun', 'kelas', 'balance', 'kelas', 'balance', 'kelas', 'luar', 'kelas', 'positif', 'kelas', 'negatif', 'kelas', 'kenal', 'himpun', 'teliti', 'cari', 'karakteristik', 'solusi', 'dekomposisi', 'aljabar', 'plus', 'simetri', 'entri', 'matriks', 'dekomposisi', 'anggota', 'kelas', 'balance', 'metode', 'kaji', 'literatur', 'teori', 'teori', 'literatur', 'kaji', 'dapat', 'karakteristik', 'matriks', 'matriks', 'entri', 'elemen', 'balance', 'milik', 'tentu', 'dekomposisiqr', 'laku', 'rkarakter', 'selesai', 'sistem', 'sama', 'milik', 'jenis', 'matriks', 'sesuai', 'tentu', 'temu'], ['teliti', 'latar', 'belakang', 'usaha', 'tentu', 'cadang', 'premi', 'tuju', 'tangan', 'klaim', 'salah', 'hitung', 'cadang', 'premi', 'cadang', 'fackler', 'metode', 'fackler', 'salah', 'hitung', 'retrospektif', 'hitung', 'metode', 'fackler', 'tentu', 'nilai', 'tunai', 'anuitas', 'tingkat', 'suku', 'bunga', 'asumsi', 'hitung', 'premi', 'bersih', 'tunggal', 'premi', 'bersih', 'tahun', 'lanjut', 'hitung', 'cadang', 'metode', 'teliti', 'metode', 'metode', 'kualitatif', 'dekat', 'studi', 'literasi', 'kaji', 'sumber', 'buku', 'kait', 'cadang', 'facklerperhitungan', 'hasil', 'formula', 'hitung', 'cadang', 'premi', 'kerja', 'metode', 'fackler', 'tentu', 'nilai', 'tunai', 'anuitas', 'tingkat', 'suku', 'bunga', 'asumsi', 'simbol', 'simbol', 'komutasi', 'hitung', 'premi', 'bersih', 'tunggal', 'premi', 'bersih', 'tahun', 'premi', 'kotor', 'tunggal', 'premi', 'kotor', 'tahun', 'lanjut', 'hitung', 'cadang', 'nilai', 'cadang', 'premi', 'metode', 'fackler', 'simulasi', 'tingkat', 'suku', 'bunga', 'repo', 'rate', 'tabel', 'mortalita', 'hasil', 'hitung', 'performa', 'metode', 'fackler', 'sederhana', 'metode', 'retrospektif', 'metode', 'fackler', 'rumus', 'komutasi', 'hitung', 'cadang', 'retrospektif', 'pakai', 'rumus', 'komutasi'], ['inflasi', 'salah', 'peristiwa', 'moneter', 'jumpa', 'negara', 'dunia', 'indikator', 'ukur', 'tingkat', 'inflasi', 'indeks', 'harga', 'konsumen', 'angka', 'gambar', 'banding', 'harga', 'konsumen', 'periode', 'beda', 'teliti', 'faktor', 'pengaruh', 'laju', 'inflasi', 'jawa', 'metode', 'metode', 'analisis', 'faktor', 'teknik', 'principal', 'component', 'analysis', 'analisis', 'faktor', 'salah', 'teknik', 'analisis', 'multivariat', 'interdependensi', 'reduksi', 'data', 'variabel', 'faktor', 'analisa', 'variabel', 'sifat', 'bebas', 'variabel', 'variabel', 'korelasi', 'variabel', 'faktor', 'hasil', 'teliti', 'analisis', 'faktor', 'oleh', 'faktor', 'bentuk', 'variabeldengan', 'sumbang', 'inflasi', 'besar', 'jawa', 'tengahtahun', 'faktor', 'variabel', 'ikan', 'segar'], ['knapsack', 'problem', 'algoritma', 'optimasi', 'tuju', 'maksimal', 'minimal', 'nilai', 'knapsack', 'optimasi', 'kombinatorial', 'pilih', 'barang', 'masuk', 'batas', 'maksimum', 'nilai', 'optimal', 'algoritma', 'masalah', 'integer', 'knapsack', 'problem', 'algoritma', 'greedy', 'dynamic', 'programming', 'brute', 'force', 'genetic', 'tuju', 'teliti', 'cari', 'untung', 'maksimum', 'masalah', 'integer', 'knapsack', 'algoritma', 'greedy', 'dynamic', 'programming', 'brute', 'force', 'genetic', 'banding', 'empat', 'algoritma', 'masalah', 'integer', 'knapsack', 'segi', 'hasil', 'komputasi', 'detik', 'hasil', 'teliti', 'data', 'barang', 'barang', 'data', 'barang', 'barang', 'tunjuk', 'untung', 'maksimum', 'guna', 'algoritma', 'greedy', 'konsep', 'greedy', 'profit', 'total', 'berat', 'komput ...

# %% [markdown]
# ## Bigrams & Trigrams

# %%
import gensim
#Create Bigram & Trigram Models
from gensim.models import Phrases
# Add bigrams and trigrams to docs, minimum count 10 means only that appear 10 times or more.
bigram = Phrases(text_list, min_count=10)
trigram = Phrases(bigram[text_list])
for idx in range(len(text_list)):
    for token in bigram[text_list[idx]]:
        if '_' in token:
            # Token is a bigram, add to document.
            text_list[idx].append(token)
    for token in trigram[text_list[idx]]:
        if '_' in token:
            # Token is a bigram, add to document.
            text_list[idx].append(token)

# %%
print(text_list)
# Out:
# [['dekomposisi', 'salah', 'dekomposisi', 'matriks', 'dekomposisi', 'matriks', 'kali', 'matriks', 'ortogonal', 'matriks', 'segitiga', 'dekomposisi', 'aljabar', 'konvensional', 'bart', 'schutter', 'bart', 'moor', 'dekomposisi', 'aljabar', 'plus', 'simetri', 'aljabar', 'plus', 'simetri', 'struktur', 'aljabar', 'himpun', 'notasi', 'operasi', 'dasar', 'ajabar', 'plus', 'struktur', 'aljabar', 'himpun', 'operasi', 'dasar', 'jumlah', 'maksimum', 'operasi', 'dasar', 'kali', 'jumlah', 'aljabar', 'plus', 'milik', 'invers', 'operasi', 'bentuk', 'aljabar', 'plus', 'simetri', 'aljabar', 'plus', 'simetri', 'milik', 'kelas', 'himpun', 'kelas', 'balance', 'kelas', 'balance', 'kelas', 'luar', 'kelas', 'positif', 'kelas', 'negatif', 'kelas', 'kenal', 'himpun', 'teliti', 'cari', 'karakteristik', 'solusi', 'dekomposisi', 'aljabar', 'plus', 'simetri', 'entri', 'matriks', 'dekomposisi', 'anggota', 'kelas', 'balance', 'metode', 'kaji', 'literatur', 'teori', 'teori', 'literatur', 'kaji', 'dapat', 'karakteristik', 'matriks', 'matriks', 'entri', 'elemen', 'balance', 'milik', 'tentu', 'dekomposisiqr', 'laku', 'rkarakter', 'selesai', 'sistem', 'sama', 'milik', 'jenis', 'matriks', 'sesuai', 'tentu', 'temu', 'aljabar_plus', 'aljabar_plus', 'aljabar_plus', 'aljabar_plus', 'aljabar_plus', 'aljabar_plus', 'aljabar_plus', 'aljabar_plus', 'struktur_aljabar', 'struktur_aljabar', 'aljabar_plus', 'aljabar_plus', 'aljabar_plus', 'aljabar_plus', 'aljabar_plus', 'aljabar_plus', 'aljabar_plus', 'aljabar_plus', 'aljabar_plus', 'aljabar_plus'], ['teliti', 'latar', 'belakang', 'usaha', 'tentu', 'cadang', 'premi', 'tuju', 'tangan', 'klaim', 'salah', 'hitung', 'cadang', 'premi', 'cadang', 'fackler', 'metode', 'fackler', 'salah', 'hitung', 'retrospektif', 'hitung', 'metode', 'fackler', 'tentu', 'nilai', 'tunai', 'anuitas', 'tingkat', 'suku', 'bunga', 'asumsi', 'hitung', 'premi', 'bersih', 'tunggal', 'premi', 'bersih', 'tahun', 'lanjut', 'hitung', 'cadang', 'metode', 'teliti', 'metode', 'metode', 'kualitatif', 'dekat', 'studi', 'literasi', 'kaji', 'sumber', 'buku', 'kait', 'cadang', 'facklerperhitungan', 'hasil', 'formula', 'hitung', 'cadang', 'premi', 'kerja', 'metode', 'fackler', 'tentu', 'nilai', 'tunai', 'anuitas', 'tingkat', 'suku', 'bunga', 'asumsi', 'simbol', 'simbol', 'komutasi', 'hitung', 'premi', 'bersih', 'tunggal', 'premi', 'bersih', 'tahun', 'premi', 'kotor', 'tunggal', 'premi', 'kotor', 'tahun', 'lanjut', 'hitung', 'cadang', 'nilai', 'cadang', 'premi', 'metode', 'fackler', 'simulasi', 'tingkat', 'suku', 'bunga', 'repo', 'rate', 'tabel', 'mortalita', 'hasil', 'hitung', 'performa', 'metode', 'fackler', 'sederhana', 'metode', 'retrospektif', 'metode', 'fackler', 'rumus', 'komutasi', 'hitung', 'cadang', 'retrospektif', 'pakai', 'rumus', 'komutasi', 'cadang_premi', 'cadang_premi', 'tingkat_suku', 'cadang_premi', 'tingkat_suku', 'cadang_premi', 'tingkat_suku', 'cadang_premi', 'cadang_premi', 'premi_bersih', 'premi_bersih', 'cadang_premi', 'premi_bersih', 'premi_bersih', 'cadang_premi', 'tabel_mortalita', 'cadang_premi', 'cadang_premi', 'tingkat_suku', 'cadang_premi', 'tingkat_suku', 'cadang_premi', 'tingkat_suku'], ['inflasi', 'salah', 'peristiwa', 'moneter', 'jumpa', 'negara', 'dunia', 'indikator', 'ukur', 'tingkat', 'inflasi', 'indeks', 'harga', 'konsumen', 'angka', 'gambar', 'banding', 'harga', 'konsumen', 'periode', 'beda', 'teliti', 'faktor', 'pengaruh', 'laju', 'inflasi', 'jawa', 'metode', 'metode', 'analisis', 'faktor', 'teknik', 'principal', 'component', 'analysis', 'analisis', 'faktor', 'salah', 'teknik', 'analisis', 'multivariat', 'interdependensi', 'reduksi', 'data', 'variabel', 'faktor', 'analisa', 'variabel', 'sifat', 'bebas', 'variabel', 'variabel', 'korelasi', 'variabel', 'faktor', 'hasil', 'teliti', 'analisis', 'faktor', 'oleh', 'faktor', 'bentuk', 'variabeldengan', 'sumbang', 'inflasi', 'besar', 'jawa', 'tengahtahun', 'faktor', 'variabel', 'ikan', 'segar'], ['knapsack', 'problem', 'algoritma', 'optimasi', 'tuju', 'maksimal', 'minimal', 'nilai', 'knaps ...

# %%
from gensim import corpora, models
# Create a dictionary representation of the documents.
dictionary = corpora.Dictionary(text_list)
dictionary.filter_extremes(no_below=5, no_above=0.2)
#no_below (int, optional) – Keep tokens which are contained in at least no_below documents.
#no_above (float, optional) – Keep tokens which are contained in no more than no_above documents (fraction of total corpus size, not an absolute number).
print(dictionary)
# Out:
# Dictionary<201 unique tokens: ['aljabar', 'aljabar_plus', 'cari', 'elemen', 'himpun']...>

# %%
from gensim import corpora, models

# Pastikan text_list sudah didefinisikan dan berisi data
if not text_list:
    raise ValueError("text_list kosong. Pastikan data sudah dimuat dengan benar.")
dictionary = corpora.Dictionary(text_list)
doc_term_matrix = [dictionary.doc2bow(doc) for doc in text_list]

print(f"Jumlah dokumen dalam doc_term_matrix: {len(doc_term_matrix)}")

# Cek apakah indeks ke-50 tersedia sebelum mengaksesnya
if len(doc_term_matrix) > 50:
    print(doc_term_matrix[50])
else:
    print(f"doc_term_matrix memiliki {len(doc_term_matrix)} dokumen, tidak cukup untuk indeks ke-50.")

tfidf = models.TfidfModel(doc_term_matrix)
corpus_tfidf = tfidf[doc_term_matrix]
print("Contoh TF-IDF untuk dokumen pertama:", list(corpus_tfidf)[0] if len(corpus_tfidf) > 0 else "Kosong")
# Out:
# Jumlah dokumen dalam doc_term_matrix: 88
# [(6, 3), (16, 1), (29, 1), (30, 1), (40, 3), (43, 1), (66, 2), (78, 4), (89, 2), (97, 2), (130, 2), (131, 1), (142, 1), (147, 3), (195, 2), (236, 6), (273, 2), (311, 1), (381, 1), (415, 1), (617, 1), (697, 3), (866, 1), (941, 2), (1157, 1), (1158, 2), (1159, 3), (1160, 1), (1161, 2), (1162, 5), (1163, 1), (1164, 1), (1165, 1), (1166, 1), (1167, 1), (1168, 3), (1169, 1), (1170, 3), (1171, 1), (1172, 1), (1173, 4), (1174, 1), (1175, 3), (1176, 1), (1177, 6), (1178, 1), (1179, 2), (1180, 1)]
# Contoh TF-IDF untuk dokumen pertama: [(0, 0.059451739993938685), (1, 0.28656129073672476), (2, 0.5731225814734495), (3, 0.041044008941440654), (4, 0.23780695997575474), (5, 0.11890347998787737), (6, 0.014739536185711145), (7, 0.025393390440177268), (8, 0.02107231102611992), (9, 0.024145488504473255), (10, 0.35173512127382767), (11, 0.059451739993938685), (12, 0.038081026046975844), (13, 0.10049574893537933), (14, 0.11044638631498814), (15, 0.05024787446768966), (16, 0.020354386394950574), (17, 0.06722644561373442), (18, 0.06722644561373442), (19, 0.07132018549380958), (20, 0.08208801788288131), (21, 0.2689057824549377), (22, 0.041044008941440654), (23, 0.05024787446768966), (24, 0.03566009274690479), (25, 0.0897279165463076), (26, 0.059451739993938685), (27, 0.03361322280686721), (28, 0.2689057824549377), (29, 0.004650117836249854), (30, 0.0571575151997678), (31, 0.059451739993938685), (32, 0.041044008941440654), (33, 0.05024787446768966), (34, 0.10582490888262311), (35, 0.05024787446768966), (36, 0.22288100390634152), (37, 0.0448639582731538), (38, 0.059451739993938685), (39, 0.010469429468228802), (40, 0.022636277888942628), (41, 0.059451739993938685), (42, 0.05024787446768966), (43, 0.026456227220655777), (44, 0.026456227220655777), (45, 0.25123937233844834), (46, 0.026456227220655777), (47, 0.038081026046975844), (48, 0.07616205209395169), (49, 0.08208801788288131), (50, 0.00160174319314338), (51, 0.03566009274690479), (52, 0.03237904982785651), (53, 0.07616205209395169)]

# %% [markdown]
# ## LDA

# %%
from gensim.models.ldamodel import LdaModel
import pyLDAvis.gensim
import pickle
import pyLDAvis
import os

pyLDAvis.enable_notebook()

for numTopic in range(2, 6):
  for passes in [100, 500, 1000, 5000]:
    print(f"numTopic: {numTopic}, passes: {passes} => Starting")
    model = LdaModel(corpus=corpus_tfidf, id2word=dictionary, num_topics=numTopic, passes=passes) #num topic
    model.save(f'{dir}/hasil LDA/LDA UIN Walisongo/LDA model/lda_model_uinwalisongo_{str(numTopic)}_{passes}')

    LDAvis_data_filepath = os.path.join(f'{dir}/hasil LDA/LDA UIN Walisongo/ldavis_prepared_uinwalisongo_{str(numTopic)}_{passes}')

    data = pyLDAvis.gensim.prepare(model, corpus_tfidf, dictionary)
    with open(LDAvis_data_filepath, 'wb') as f:
        pickle.dump(data, f)

    # load the pre-prepared pyLDAvis data from disk
    with open(LDAvis_data_filepath, 'rb') as f:
        data = pickle.load(f)

    pyLDAvis.save_html(data, f'{dir}/hasil LDA/LDA UIN Walisongo/{str(numTopic)}_{passes}.html')

    # print(data)
    print(f"numTopic: {numTopic}, passes: {passes} => Success")
# Out:
# numTopic: 2, passes: 100 => Starting
# numTopic: 2, passes: 100 => Success
# numTopic: 2, passes: 500 => Starting
# numTopic: 2, passes: 500 => Success
# numTopic: 2, passes: 1000 => Starting
# numTopic: 2, passes: 1000 => Success
# numTopic: 2, passes: 5000 => Starting
# numTopic: 2, passes: 5000 => Success
# numTopic: 3, passes: 100 => Starting
# numTopic: 3, passes: 100 => Success
# numTopic: 3, passes: 500 => Starting
# numTopic: 3, passes: 500 => Success
# numTopic: 3, passes: 1000 => Starting
# numTopic: 3, passes: 1000 => Success
# numTopic: 3, passes: 5000 => Starting
# numTopic: 3, passes: 5000 => Success
# numTopic: 4, passes: 100 => Starting
# numTopic: 4, passes: 100 => Success
# numTopic: 4, passes: 500 => Starting
# numTopic: 4, passes: 500 => Success
# numTopic: 4, passes: 1000 => Starting
# numTopic: 4, passes: 1000 => Success
# numTopic: 4, passes: 5000 => Starting
# numTopic: 4, passes: 5000 => Success
# numTopic: 5, passes: 100 => Starting
# numTopic: 5, passes: 100 => Success
# numTopic: 5, passes: 500 => Starting
# numTopic: 5, passes: 500 => Success
# numTopic: 5, passes: 1000 => Starting
# numTopic: 5, passes: 1000 => Success
# numTopic: 5, passes: 5000 => Starting
# numTopic: 5, passes: 5000 => Success
